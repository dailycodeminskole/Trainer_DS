# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# using a to dataset IRIS

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
# getting to know about the dataset
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info() # there are no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include="all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
# finding number of unique values in species
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# distribution of petal length data
# hstogram
sns.histplot(data=iris['petal_length'],bins=20)
plt.show()

# default addition of labels and borders around the bars
# we can clearly see that more patals are with shorter lenght
#  there are two group of lenghts

# %% [markdown]
# # KDE

# %%
# kernel density plot
sns.kdeplot(iris['petal_length'])
plt.show()
# shows two groups of data
# y-axis show the probailty of finding a petal lenght 
# bimodal plot

# %% [markdown]
# # SCATTER

# %%
# to get the relationship between two numeric values
sns.scatterplot(x=iris['petal_length'],y=iris['petal_width'])
plt.show()

# again we see there are two groups
# directly proportional

# %%
sns.scatterplot(x="petal_length",y='petal_width',data=iris,hue='species')
# we can see there are three clusters
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load iris dataset
iris = sns.load_dataset('iris')

# Create subsets for each species
setosa = iris.loc[iris['species'] == 'setosa']
versicolor = iris.loc[iris['species'] == 'versicolor']
virginica = iris.loc[iris['species'] == 'virginica']

# Create scatter plot
plt.scatter(x=setosa['petal_length'], y=setosa['petal_width'], c='blue', label='Setosa')
plt.scatter(x=versicolor['petal_length'], y=versicolor['petal_width'], c='orange', label='Versicolor')
plt.scatter(x=virginica['petal_length'], y=virginica['petal_width'], c='green', label='Virginica')

# Add labels and legend
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Iris Dataset')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# # JOINTPLOT

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind='reg') #adding the regression line with confidence interval

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,hue='species') #adding the regression line with confidence interval
plt.show()

# %% [markdown]
# # ALL INFO

# %% [markdown]
# # pair plot

# %%
sns.pairplot(data=iris,hue='species')
plt.plot()
# Out:
# []

# %% [markdown]
# # COUNT PLOT

# %%
# categorical data 
# ie non numerical data analysys

# %%
# we can plot bar plot
# countplot
sns.countplot(x='species',data=iris)
plt.show()

# %% [markdown]
# # BOXPLOT

# %%
sns.boxplot(x='species',y='sepal_length',data=iris)
plt.show()
# median vlaue

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # VIOLIN PLOT

# %%
sns.violinplot(x='species',y='sepal_length',data=iris)
plt.show()
# also gives the distribution of the data
# too much info
# not clear
# symmetrical plot

# %% [markdown]
# # CORRELATION

# %%
# finding the correaltion betwnn diff values parameter
# we will find the coeff of coerrelation
# can be positive or negative

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.pairplot(data=iris,hue='species')
plt.plot()
# Out:
# []

# %%
# plotting the heatmap

# %%
sns.heatmap(iris.corr(),cmap='Greens',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2ND DATA SET

# %%
tips = sns.load_dataset('tips')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# count of sex 
sns.countplot(x=tips['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# unique number of day
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# num-cat
# number of females on a paricular day
sns.countplot(x="day",data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
# num-num-cat day-time-total bill
sns.barplot(x='day',y='total_bill',hue='time',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Deciding the Plot

# %%
# https://docs.google.com/spreadsheets/d/1qoL1rQKJdOBHjZbPBr7ksJ_SaWYaKVCj8MFvBGiTTh8/edit?usp=sharing

# %% [markdown]
# ![image.png](attachment:image.png)
