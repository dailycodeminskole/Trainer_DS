# %% [markdown]
# # data visialisation

# %%
import matplotlib.pyplot as plt # used in EDA
import numpy as np
import pandas as pd

# %% [markdown]
# # Plotting a basic Line Plot

# %%
x_val = [0,1,2]
plt.plot(x_val)
#default integer for y-axis will be used

# %%
y_val = [3,5,9]
plt.plot(y_val)
#default integer for x-axis will be used

# %%
# x_val = [0,1,2]
y_val = [3,5,9]
# plt.plot(x_val,y_val)#default line plot as we have not mentioned the type of plot here
plt.plot(y_val)#default integer for x-axis will be used

# %%
x_val = [0,1,2]
y_val = [3,5,9]
plt.plot(x_val,y_val)
#default line plot as we have not mentioned the type of plot here

# %% [markdown]
# # Anatomy of a plot

# %%
# https://matplotlib.org/stable/gallery/showcase/anatomy.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# axes is plural of axis
# we should use the term PLOT and not the graph

# %% [markdown]
# #  saving a figure

# %%
plt.plot(y_val)
plt.savefig('first.jpg')

# %% [markdown]
# # creating more plots

# %%
x_val = [-3,-2,-1,0,1,2,3]
y_val = [9,4,1,0,1,4,9]
plt.plot(x_val,y_val)

# %%
# using numpy to get the same points
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)

# %%
# More precise ticks
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)
plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %%
# addding labels and title

# %%
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)

plt.title("Square")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %%
# changing theme color,
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val,'ro') #  * + --  other can also be used


plt.title("Square")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %%
#  zooming IN  --- accessing only limited part of the plot
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)


plt.xlim(1,3)#limited view
plt.title("Square")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
# zooming out plot -- Birds Eyeview
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)


plt.xlim(-10,10)#limited view
plt.ylim(0,5)#limited view for y axis zoom in 

plt.title("Square")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
# Multile plots in same canvas ( default in differnt colors)
x_val = np.arange(-3,3,0.1)
y_1 = x_val**2
y_2 = x_val**3

plt.plot(x_val,y_1)
plt.plot(x_val,y_2)

# %%
# adding legend

x_val = np.arange(-3,3,0.1)
y_1 = x_val**2
y_2 = x_val**3

plt.plot(x_val,y_1)
plt.plot(x_val,y_2)

# %% [markdown]
# # Data visualisation

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Basics of a graph
# how do we use a graph
# x axis 
# y axis
# https://matplotlib.org/stable/gallery/showcase/anatomy.html

# %% [markdown]
# # Anatomy of a plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_val = [0,1,2]
y_val = [3,5,9]
plt.plot(x_val,y_val)
plt.show()

# %%
# axes is plural of axis
# we should use the term PLOT and not the graph

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  saving a figure

# %%
plt.plot(y_val)
plt.plot(x_val)
plt.savefig('my_plot1.jpg')

# %% [markdown]
# # creating more plots

# %%
x_val = [-3,-2,-1,0,1,2,3]
y_val = [9,4,1,0,1,4,9]
plt.plot(x_val,y_val)

# %%
# using numpy to get the same points
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)

# %% [markdown]
# # More precise ticks

# %%
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)
plt.xticks(np.arange(-3,3,0.3)) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %%
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)
plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %% [markdown]
# # adding labels and title

# %%
x_val = np.arange(-3,3,0.1)
y_val = x_val**2
plt.plot(x_val,y_val)
plt.title('x** functions')
plt.xlabel('x-labels')
plt.ylabel('y-labels')
plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %% [markdown]
# # changing theme color

# %%
x_val = np.arange(-3,3,0.1)
y_val = x_val**2

plt.plot(x_val,y_val,color='red')

plt.title("Square")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %%
x_val = np.arange(-3,3,0.1)
y_val = x_val**2

plt.plot(x_val,y_val,'ro') #  * + --  other can also be used


plt.title("Square")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.xticks(np.arange(-3,3,0.3),rotation=90) #more partitions in x-axis, rotation for clear visibility
plt.show()

# %% [markdown]
# #  zooming IN  --- accessing only limited part of the plot
